# %%
a = int(input("enter a number"))
b = int(input("enter a number"))
c = int(input("enter a number"))

if a>b:
    if a>c:
        print(a)
    else:
        print(c)
  
else:
    if b>c:
        print(b)
    else:
        print(c)
# Out:
# 5

# %% [markdown]
# wap to print sum of first 10 natural natural number

# %%
i = 1
val = 0
while (i<=10):
    val = val+i
    i+=1
print(val)
# Out:
# 55

# %%
i = 1
pro  = 1
while (i<=10):
    pro = pro*i
    i+=1
print(pro)
# Out:
# 3628800

# %% [markdown]
# wap to extract all the upper case alphabet form given string

# %%
a= 'Amit kumar'
out = ''
i = 0
while i<len(a):

    if 'A'<=a[i]<='z':
        out+= a[i]  
    i+=1
    print(out)
# Out:
# A
# Am
# Ami
# Amit
# Amit
# Amitk
# Amitku
# Amitkum
# Amitkuma
# Amitkumar

# %% [markdown]
# wap to extract vowel and return count of vowel

# %%
a= 'Amiit kumar'
out = ''
i = 0
count = 0
while i<len(a):

    if a[i] in 'aeiouAEIOU':
        out += a[i] 
        count=count+1
    i+=1
print(out)
print(count)
# Out:
# Aiiua
# 5

# %%
a='DAta ScieNCE'   
out = ''
i = 0
count = 0
while i<len(a):
    if 'A'<=a[i]<='Z':
        out+= a[i]
        # con = out+str(count)
        count=count+1
        
    i+=1
print(out+str(count))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 12
#       9         count=count+1
#      11     i+=1
# ---> 12 print(out+str(count))
#
# TypeError: 'str' object is not callable

# %% [markdown]
# wap take a list extract integer from given list

# %%
list = [1,2,3,4,5,6,'hello']
out  = []
i = 0  
while i<len(list):
   if type(a[i ])==int:
      out+=[a[i ]]
      i+=1
print(out)

# %% [markdown]
# extract all the spaicel char from email id

# %%
email = 'anshsingh841216@gmail.com'
out = ''
i = 0

while i<len(email):

    if email[i  ] in '!@#$%^&*()':
        out += email[i] 
        
    i+=1
print(out)
# Out:
# @

# %%
email = 'anshsingh841216@gamil.com' 
out = ''
i = 0 
while i <len(email):
    if not email[i]
