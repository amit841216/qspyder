# %%
a = 'abcdabcb'

j = ' '
for i in a:
    if 'a' <= i <= 'z':
        j+=i+str(ord(i)-96)
print(j)
# Out:
#  a1b2c3d4a1b2c3b2

# %%
num = int(input("enter a num"))
fact = 1
for i in range(1,num+1):
    fact*=i
print(fact)
# Out:
# 120

# %%
num = int(input("enter a num"))
fact = 1
for i in range(1,num+1):
    fact*=i
print(fact)
# Out:
# 120

# %%
a = [111,'hello',12,3+5j,7777,69,9.8]   
out = []
for i in a:
    if type(i)==int and str(i)==str(i)[::-1]:
        out+=[i,len(str(i))]
print(out)
# Out:
# [111, 3, 7777, 4]

# %%
a = 'hai hello'.split()  
out = {}
for i in a :
    out[i]=[i,len(i)*2,i[::-1]+str(len(i)*2)]
print(out)
# Out:
# {'hai': ['hai', 6, 'iah6'], 'hello': ['hello', 10, 'olleh10']}

# %%
a = 'amit kumar'.split()
out= {}
for i in a:
    out[i]= [i,len(i )*2 , i[::-1]+str(len(i)*2)]
print(out)
# Out:
# {'amit': ['amit', 8, 'tima8'], 'kumar': ['kumar', 10, 'ramuk10']}

# %%
a = 'python is programming language'.split()
out = {}
for i in a:
    if i[0] not in out:
        out[i[0]]=[i]
    else:
        out[i[0]]+=[i]
print(out)
# Out:
# {'p': ['python', 'programming'], 'i': ['is'], 'l': ['language']}

# %%
a = 'python is programming language'.split()
out = {}
for i in a:
    if i[0] not in out:
        out[i[0]] = [i  ]
    else:
        out[i[0 ]] +=[i ]
print(out)
# Out:
# {'p': ['python', 'programming'], 'i': ['is'], 'l': ['language']}

# %%
a = 'python is programming  language and high level language'.split()
out = {}
for i in a:
    if i[0] not in out:
        out[i[0]] = [i]
    else:
        out[i[0]] +=[i]
print(out)
# Out:
# {'p': ['python', 'programming'], 'i': ['is'], 'l': ['language', 'level', 'language'], 'a': ['and'], 'h': ['high']}

# %%
# output = 'bcdtuva'
a = 'abcstuz'
out = ''
for i in a:
    if i== 'z':
        out+='a'
    else:
        out+=chr(ord(i)+1)
print(out)
# Out:
# bcdtuva

# %%
a = 'abcstuz'
out = ''
for i in a:
    if i == 'z':
        out+= 'a'
    else:
        out+=chr(ord(i)+1)
print(out)
# Out:
# bcdtuva

# %%
# output = ['com','html','py','in']

a = ['google.com', 'pw.html', 'index.py','gmail.com','yahoo.in']
out = []
for i in a:
    parts = i.split('.')
    out.append(parts[-1])
print(out)
# Out:
# ['com', 'html', 'py', 'com', 'in']
