# %% [markdown]
# input is a = 'aabcdcabc'
# output is  = 'a4b2c2d1'

# %%
a= 'aabcdcaba'
b = 'aaabbccd'

out = ''
i = 0 
while i < len(a):
    while i<len(a   ):

        if a[i]not in out:
            out +=a[i]+str(a.count(a[i]))
            
        i+=1
print(out)
# Out:
# a4b2c2d1

# %% [markdown]
# wap to print the factorial of the number

# %%
num = int(input("enter a number"))
i = 1
out = 1
while i <=num:
    out = out*i
    i+=1
print(out)
# Out:
# 40320

# %% [markdown]
# wap table

# %%
num = int(input("enter a number"))
i = 0
while i <=10:
    print(num,"x", i,"=",num*i) 
    i+=1
# Out:
# 4 x 0 = 0
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %% [markdown]
# input is a = 987
# output = 24

# %%
n = 987
sum = 0
rev =0
while n != 0:
    val =n%10
    sum += val
    rev = rev*10+val
    n = n //10
print(sum)
print(rev)
# Out:
# 24
# 789

# %%
a = ['str',[1,3,4],'ab',98,1.5,3+5j,'hello']
out = []
while i < len(a):
    if type(a[i])== str and len(a[i])>3:

        out.append(a[i])
    i+=1
print(out)
# Out:
# []
