# %%
def an():
    a = 'python'    
    out = ''

    for i in a:
        if i==  a[0] :
            out+=chr(ord(i)-32)
               
        else:
            out+=i
    print(out)
an()
# Out:
# Python

# %%
a = '101$01!001~0'
out = ''
for i in a:
    if i  == '1':
        out+='0'
    elif i == '0':
        out+='1'
    else:
        out+='#'
print(out)
# Out:
# 010#10#110#1
