# %%
name = 'python'
print(name[0:3])
print(name[3:6])
print(name[0:6:2])
print(name[0:6:3])
print(name[1:6:3])
# Out:
# pyt
# hon
# pto
# ph
# yo

# %%
numbers = [1,3,4,5,6]
numbers.append(7)
print(numbers)
numbers.insert(0,34)
print(numbers)
numbers.remove(34)
print(numbers)
numbers.pop(2)
print(numbers)
print(len(numbers))
# Out:
# [1, 3, 4, 5, 6, 7]
# [34, 1, 3, 4, 5, 6, 7]
# [1, 3, 4, 5, 6, 7]
# [1, 3, 5, 6, 7]
# 5

# %%
n = 5,7,2,3,0,9
cout = 1
for i in n:
    if n%10:
# Out:
# 0
# 0
# 0

# %%
a = {1,2,4,5}
print(a)
a.add(33)
print(a)
a.add(22)
print(a)
a.remove(2)
print(a)
# Out:
# {1, 2, 4, 5}
# {1, 2, 33, 4, 5}
# {1, 2, 33, 4, 5, 22}
# {1, 33, 4, 5, 22}

# %%
s = {10, 20, 30}
print(s)
# Out:
# {10, 20, 30}

# %%
a = [5,10,15,20]
a.remove(10)
a.pop()
a.insert(1, 99)
print(a)
# Out:
# [5, 99, 15]

# %%
n = [10,20,30,40]
cout = 0
for i in n:
    cout+=i
print(cout)
# Out:
# 100

# %%
number = [3,877,23,987,2,345]
max_num = number[0]
for i in number:
    if i > max_num:
        max_num = i
print(max_num)
# Out:
# 987

# %%
number = [3,877,23,987,2,345]
min_num = number[0]
for i in number:
    if i<min_num:
        min_num = i
print(min_num)
# Out:
# 2

# %%
a = [1,2,3,4,5]
rev = []
for i in range(len(a)-1,-1,-1):
    rev.append(a[i])
print(rev)
# Out:
# [5, 4, 3, 2, 1]

# %%
a = [1,2,3,4,5]
odd_numbers = []
for i in a:
    if i%2 != 0:
        odd_numbers.append(i)
print(odd_numbers)
# Out:
# [1, 3, 5]

# %%
a = [1,2,3,4,5]
odd= 1
even = 1
for i in a:
    if i % 2 != 0:
        odd*=i
print("this multiply of odd",odd)
# Out:
# this multiply of odd 15

# %%
a =[1, [2,3], [4,5], 6]
flat_list= []
for i in a:
    if  type(i) == list:
        for x in i:
            flat_list.append(x)
    else:
        flat_list.append(i)
        
print(flat_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a =[1, [2,3], [4,5], 6] 
new_list = []
for i in a:
    if type(i) == list:
        for x in i:
            new_list.append(x)
    else:
        new_list.append(i)
print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1,2,2,3,3]
freq = {}
for i in a:
    if i in freq: 
        freq[i] +=1
    else:
        freq[i] = 1
print(freq)
# Out:
# {1: 1, 2: 2, 3: 2}

# %%
a = [1,2,2,3,3,3,4]
unique= []
for i in a:
    if i  not in  unique:
        unique.append(i)
print(unique)
# Out:
# [1, 2, 3, 4]

# %%
a = [1,2,2,3,3,3,4]
unique = list(set(a))
print(unique)
# Out:
# [1, 2, 3, 4]

# %%
for i in range(3):
    for j in range(3):
        print("*", end=" ")
    print()
# Out:
# * * *
# * * *
# * * *

# %%
for i in range(1,5):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *

# %%
nums = [2,4,6,3,7,8]

for i in range(len(nums )):
    for j in range(i+1,len(nums)):
        if nums[i] + nums[j] == 10:
            print(nums[i] ,'+' ,nums[j] ,'=',nums[i] + nums[j] )
# Out:
# 2 + 8 = 10
# 4 + 6 = 10
# 3 + 7 = 10

# %%
for i in range(1,4):
    for j in range(1,4):
        print(i*j , end = " ")
    print()
# Out:
# 1 2 3
# 2 4 6
# 3 6 9

# %%
for i in range(1,5):
    for j in range(1, i+1):
        print(j , end= "")
    print()
# Out:
# 1
# 12
# 123
# 1234

# %%
for i in range(4 , 0 , -1):
    for j in range(1 , i+1):
        print("*" , end= "")
    print()
# Out:
# ****
# ***
# **
# *

# %%
for i in range (1,5):
    for j in range(4 , i-1 , -1):
        print(j, end = "")
    print()
# Out:
# 4321
# 432
# 43
# 4

# %%
a = "hello"
print(a.find("l"))   # 2
# Out:
# 2

# %%
a = "python.py"
print(a.endswith("py"))   # True
# Out:
# False

# %%
name = "Aman"
age = 20
print("My name is {} and I am {}".format(name,age))
print(f"My name is {name} and I am {age}")
# Out:
# My name is Aman and I am 20
# My name is Aman and I am 20

# %%
a = "banana"
print(a.count("an"))
# Out:
# 2

# %%
a = "PyThOn ProGRamMiNg"
print(a.lower())
# Out:
# python programming

# %%
a = "   hello world   "
print(a.strip())
# Out:
# hello world

# %%
a = "programming"
print(a.count("a") + a.count("e") + a.count("i") + a.count("o") + a.count("u"))
# Out:
# 3

# %%
a = "I like Java"
print(a.replace("Java","python"))
# Out:
# I like python

# %%
username = "user123"
print(username.isalnum())
# Out:
# True

# %%
a = "python"
print(a[::-1])
# Out:
# nohtyp

# %%
a = "madam"
if a==a[::-1]:
    print("its palindrome")
else:
    print("its not palindrome")
# Out:
# its palindrome

# %%
a = "index.html"
print(a.split(".")[-1])
# Out:
# html

# %%
a = "python is fun"
print(a.title())
# Out:
# Python Is Fun

# %%
a = 'python is very easy'
print(len(a.split()))
# Out:
# 4

# %%
a = input("enter a name").lower()
if a == a[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
a = 'programming'
count = 0

if a in 'aeiouAEIOU':
    E

# %%
a = 'programming'
total_chars = len(a)
count= 0
vowels = 'aeiouAEIOU'
if a == len(vowels):
    count+= vowels

vowel_per = (total_vowels / total_chars)*100
print("total_character = " , total_chars)
print("total vowels  = ", vowel_count)
print("total vowel percentage" ,vowel_per)



# print(len(a))
# Out:
# total_character =  11
# total vowels  =  3
# total vowel percentage 0.0

# %%
email = input("enter email")
# if 'a'<=email <='z' and email == '@'and email == '.':
if "@" in email and "." in email :

    print("valid email")
else:
    print("invalid email")
# Out:
# invalid email

# %%
a = "banana".split()
for  i in len(a):
    if

# %%
a = "programming"
out= list(dict.fromkeys(a   ))
print(str(out))
# Out:
# ['p', 'r', 'o', 'g', 'a', 'm', 'i', 'n']
