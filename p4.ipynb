# %% [markdown]
# wap to check the char is upper case

# %%
a = 'ASDF'
if a.upper():
    print("its upper")
# Out:
# its upper

# %%
char = input("enter a number")
if ('a'<= char <= 'z'):
    print("upper")

# %% [markdown]
# wap to check the str is plandrone

# %%
a = input("enter a str name")
if a==a[::-1]:
    print("pallindrome")
# Out:
# pallindrome

# %% [markdown]
# wap to check even or odd

# %%
a=eval(input("enter a number") )  
if a%2==0:
    print('its even')
else:
    print("its odd")
# Out:
# its odd

# %% [markdown]
# wap to chec the cher is vowel of constent

# %%
vowel = input("enter vower number")


if vowel == 'AEIOUaeiou':
    print("its vowel words")
else:
    print("its not vowel words")
# Out:
# its not vowel words

# %% [markdown]
# wap to check multivalue data type or single value datatypes

# %%
a = eval(input("enter a data type"))
if type(a)  in [list,tuple,set,dict]:
    print("multi")
else:
    print("single")
# Out:
# multi

# %% [markdown]
# wap to check is th number is even print cube of it if  number is odd print squire it.

# %%
num = int(input("enter a number"))
if num%2==0:
    print(num**3)
else:
    print(num**2)
# Out:
# 169

# %% [markdown]
# check the cher is special char

# %%
a = input("enter a spacial char")
if ('A'<= a <='Z' or 'a'<= a <='z' or '0' <= a <='9'):
    print("not spacial char")
else:
    print( "spacial char")
# Out:
# spacial char

# %%
a=[1,2]
if type(a[0]) == type(a[1]):
    print("homogeneous")    
else:
    print("hectogeneous")
# Out:
# homogeneous
