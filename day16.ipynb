# %% [markdown]
# wap to extract all the float value from a list

# %%
a = [1,3,4,5,2.3,3.4,5.3,12]
out = []
i = 0
while   i<len(a ):
    if type (a[i])==float and i%2==0L
        print(a[i   ])
# Out:
#   Cell In[1], line 5
#     if type (a[i])==float and i%2==0L
#                                    ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Count

# %%
a = 'hello'
print(a.count(l))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 a = 'hello'
# ----> 2 print(a.count(l))
#
# NameError: name 'l' is not defined

# %%
a = 'aabcdabcd'
i = 0
out = {}
while i<len(a):
    out[a[i]]=a.count(a[i])
    i+=1
    
print(out)
# Out:
# {'a': 3, 'b': 2, 'c': 2, 'd': 2}

# %%
a = 'python is very easy'.split()
i = 0
out={}
while i <len(a):
    
    out[a[i ]]=a[i  ][::-1] 
    i+=1
print(out)
# Out:
# {'python': 'nohtyp', 'is': 'si', 'very': 'yrev', 'easy': 'ysae'}

# %%
a = 'python is very easy'.split()
i = 0
out={}
while i <len(a):
    if i%2==0:
        out[a[i ]]=a[i  ][::-1]
    else:
        out[a[i ]]=len(a[i])*2
    i+=1
print(out)
# Out:
# {'python': 'nohtyp', 'is': 4, 'very': 'yrev', 'easy': 8}

# %%
a = 'python is very easy'.split()
i = 0
out={}
while i <len(a):
    if i%2==0 :
        out[a[i ]]=a[i  ][::-1]+str(len(a[i]))
    else:
        out[a[i ]]=len(a[i])*2
    i+=1
print(out)
# Out:
# {'python': 'nohtyp6', 'is': 4, 'very': 'yrev4', 'easy': 8}
