# %%
a = '72331'
sum_if = int(a[0])+int(a[-1])
sum = 0
for i in range(1, len(a )-1):
    if sum_if == sum:
        print("xylem")
    else:
        print('pheome')
# Out:
# pheome
# pheome
# pheome

# %% [markdown]
# wap to crated login condition

# %%
email_id = 'angelpriya@gmail.com'
while True:
    email = input('enter your email id')    
    if email_id == email:
        print("login sucessful")
        break
    else:
        print("invelid email id")
# Out:
# invelid email id
# login sucessful

# %%
num = 4

while True:
    a = int(input("enter a number"))
    if num==a:
        print("you win 7 crore")
        break
    else :
        print('you fall')
# Out:
# you fall
# you win 7 crore

# %%
num = int(input("enter the number"))
for i in range(2,num):
    if num%i ==0:
        print("composetive num")    
        break
else:
    print("prime num")
# Out:
# composetive num

# %%
a= eval(input["enput the number"])
b= eval(input("enput the number"))
c= eval(input("enput the number"))
d = eval(input("enput the number"))
if type(a==b and a==c and a==d  and b == c and b==d and c==d    ):
    print("homogeneos")
else:
    print("hextoginious")
# Out:
# homogeneos

# %%
a = [1,3,5,'HELLO',5,7,8]   
for i in range(len(a    )):
    if type a[0] != type(a[i])
