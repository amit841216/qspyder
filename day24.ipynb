# %%
for i in range(1,10,2):
    for j in range(2,7,3):
        print(i,j, end= " ")
# Out:
# 1 2 1 5 3 2 3 5 5 2 5 5 7 2 7 5 9 2 9 5

# %%
a = 'how are you all'.split()
out = [ ]
for i in a:
    c = 0
    for j in i:
        if j in 'aeiouAEIOU':
            c+=1
    out+=[i]
    # out.append(a[i])
print(out)
# Out:
# ['how', 'are', 'you', 'all']

# %%
out = []
for i in range(1,11):
    fact = 1
    for j in range(1,i+1):
        fact*=j
    out+=[fact]
print(out)
# Out:
# [1, 2, 6, 24, 120, 720, 5040, 40320, 362880, 3628800]

# %%
a = [10,'Hello', 3+5j, 321]
cout = []

for i in a:
    if  type(a[i]) == int:
        k = 0
    for j in len(a[i]):
        cout+=1
    cout.append(k)
print(cout)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 5
#       2 cout = []
#       4 for i in a:
# ----> 5     if  type(a[i]) == int:
#       6         k = 0
#       7     for j in len(a[i]):
#
# IndexError: list index out of range

# %%
a = [10,'Hello', 3+5j, 321]
cout = []

for i in a:
    if  type(i) == int:
        k = 0
    for j in str(i):
        cout+=int(j)
        cout+=[cout]
print(cout)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 8
#       6         k = 0
#       7     for j in str(i):
# ----> 8         cout+=int(j)
#       9         cout+=[cout]
#      10 print(cout)
#
# TypeError: 'int' object is not iterable

# %%
a = 'kabab is love'.split()
out = {}
for i in a:
    
    c = 0 
    for j  in i:
        if j in 'aeiou':

            c+=1
        out[i ] = [i[::-1],c,i[: : 2]]
    
print(out)
# Out:
# {'kabab': ['babak', 2, 'kbb'], 'is': ['si', 1, 'i'], 'love': ['evol', 2, 'lv']}
