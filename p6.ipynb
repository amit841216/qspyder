# %% [markdown]
# wap to check num is divis of 5 and its an even number and odd number

# %%
num= eval(input("enter the num"))
if num%5==0:
    if num%2==0:
        print("evernand div by 5")
    else:
        print("odd")
else:
    print("not div by 5")
# Out:
# odd

# %% [markdown]
# wap to check if data is multi value or single value and ist length should be more then 5

# %%
a = int(input("enter a number"))

if type(a) in [tuple , list, dict, set]:
    if len(a)>5:
        print("multiple and len is 5")
    else:
        print("multiple and not len is 5")
else:
    print('single')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 a = int(input("enter a number"))
#       3 if type(a) in [tuple , list, dict, set]:
#       4     if len(a)>5:
#
# ValueError: invalid literal for int() with base 10: '(2,3)'

# %% [markdown]
# wap to check the char is consonent or vowel

# %%
char = input("enter a numbaer")
if 'A'<= char<='Z' or 'a'<=char <='z':
    if char in 'AEIOUaeiou':
        print("VOWEL")
    else:
        print('consonent')
else:
    print("char not")
# Out:
# char not

# %% [markdown]
# wap to find a grestest number among 3 numers using nested

# %%
a= input("enter a number")
b= input("enter a number")
c= input("enter a number")
if type(a) in [int,float] and type(b) in [int,float] and type(c) in [int,float]:
    if a>b and a>c:
        print(f"{a} is gretest number")
    if b>c:
        print(f"{b} is gretest number")
    else:
        print(f"{c} is gretest number")
else:
    print("its not integer number")
# Out:
# its not integer number

# %%
a= input("enter a number")
b= input("enter a number")
c= input("enter a number")
if a>b:
    if a>c:
        print(a)
    else:
        print(c)
else:
    if b>c:
        print(b)
    else:
        print(c)
# Out:
# 7

# %% [markdown]
# wap to make a loging condition using nested

# %%
a =input("enter email")
b = input ("pasword")
email = 'anshsingh@gmail.com'
password = '1234'

if email == a:
    if password == b:
        print('login sucussful')
    else:
        print('wrong pass')
else:
    if password == b:
        print('right pass')
    print('wrong email')
# Out:
# wrong email
