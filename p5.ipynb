# %% [markdown]
# wap to chick single degit , double, tirple, four digit number

# %%
num = int(input("enter a number"))
if 0<=num<=9:
    print ('1-digit')
elif 10<=num<=99:
    print("2-digit")
elif 100<=num<=999:
    print("3-digit")
elif 1000<=num<=9999:
    print("4-digit")
# Out:
# 1-digit

# %% [markdown]
# wap to check the charactrics upper case , lower case, number , spacial char

# %%
num =input("enter a number")
if ('A'<= num<='Z'):
    print("upper case")
elif ('a'<=num<='z'):
    print("lower case")
elif ('0'<= num<='9'):
    print("number")
else:
    print("spacial char")
# Out:
# spacial char

# %% [markdown]
# make a markshit

# %%
num = int(input("enter a number"))
if (1<=num<=29):
    print("you are poor")
elif (30<=num<=45):
    print("you are best")
elif (46<=num<=90):
    print("your are good")  
else:
    print("you are exclent")
# Out:
# you are poor

# %% [markdown]
# wap to check number divigble is 3 so fizz and 5 is buzz and 3&5 is fizzbuzz

# %%
num = int(input("enter a number"))
if num%3==0 and num%5 == 0 :
    print("fixxbuzz")
elif num%3==0:
    print("fizz")
elif num%5==0:
    print("buzz")
# Out:
# fizz

# %% [markdown]
# wap pick the greteast number in four numbers

# %%
a = float(input('enter a number'))
b = float(input('enter a number'))
c = float(input('enter a number'))
d = float(input('enter a number'))
if a>b and a>c and a>d:
    print(a)
elif  b>c and b>d:
    print(b)
elif c>d:
    print(c)
else:
    print(d)
# Out:
# 34.0
